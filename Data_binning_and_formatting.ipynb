# %% [markdown]
# <a href="https://colab.research.google.com/github/JahnviShukla09/Data-Binning-and-Formatting/blob/main/Data_binning_and_formatting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment- 13
# ##Title- Data Binning and Data Formatting using Python.
# ##Jahnvi Shukla
# ##PRN-25070123055
# ##ENTC A3

# %%
import pandas as pd
import numpy as np

data = {
    'Product':['Laptop', 'Mobile', 'Tablet', 'Headphones', 'Smartwatch','Camera'],
    'Price': [55000, 20000, 30000, 2000, 8000, 450000],
    'Units_Sold': [25,60,35,80,50,15]
}

df=pd.DataFrame(data)

print("Dataset")
df
# Out:
# Dataset
#       Product   Price  Units_Sold
# 0      Laptop   55000          25
# 1      Mobile   20000          60
# 2      Tablet   30000          35
# 3  Headphones    2000          80
# 4  Smartwatch    8000          50
# 5      Camera  450000          15

# %%
#Data Binning
bins=[0,10000,30000,60000]
labels=['Low','Medium','High']
df['Price_Category'] = pd.cut(df['Price'],bins=bins, labels=labels)
df
# Out:
#       Product   Price  Units_Sold Price_Category
# 0      Laptop   55000          25           High
# 1      Mobile   20000          60         Medium
# 2      Tablet   30000          35         Medium
# 3  Headphones    2000          80            Low
# 4  Smartwatch    8000          50            Low
# 5      Camera  450000          15            NaN

# %%
#Binning Units Sold
bins2=[0,30,60,100]
labels2=['Low Sales', 'Medium Sales', 'High Sales']

df['Sales_Category'] = pd.cut(df['Units_Sold'],bins=bins2, labels=labels2)
df
# Out:
#       Product   Price  Units_Sold Price_Category Sales_Category
# 0      Laptop   55000          25           High      Low Sales
# 1      Mobile   20000          60         Medium   Medium Sales
# 2      Tablet   30000          35         Medium   Medium Sales
# 3  Headphones    2000          80            Low     High Sales
# 4  Smartwatch    8000          50            Low   Medium Sales
# 5      Camera  450000          15            NaN      Low Sales

# %%
#Data Formatting
#Convert Data Type

print(df.dtypes)

df['Units_Sold'] = df['Units_Sold'].astype(float)
df['Price'] = df['Price'].astype(float)
df
# Out:
# Product             object
# Price                int64
# Units_Sold           int64
# Price_Category    category
# Sales_Category    category
# dtype: object
#       Product     Price  Units_Sold Price_Category Sales_Category
# 0      Laptop   55000.0        25.0           High      Low Sales
# 1      Mobile   20000.0        60.0         Medium   Medium Sales
# 2      Tablet   30000.0        35.0         Medium   Medium Sales
# 3  Headphones    2000.0        80.0            Low     High Sales
# 4  Smartwatch    8000.0        50.0            Low   Medium Sales
# 5      Camera  450000.0        15.0            NaN      Low Sales

# %%
# Convert Text to Uppercase
df['Product'] = df['Product'].str.upper()
df
# Out:
#       Product     Price  Units_Sold Price_Category Sales_Category
# 0      LAPTOP   55000.0        25.0           High      Low Sales
# 1      MOBILE   20000.0        60.0         Medium   Medium Sales
# 2      TABLET   30000.0        35.0         Medium   Medium Sales
# 3  HEADPHONES    2000.0        80.0            Low     High Sales
# 4  SMARTWATCH    8000.0        50.0            Low   Medium Sales
# 5      CAMERA  450000.0        15.0            NaN      Low Sales

# %%
#Additional Operations
#Sorting Data

sorted_df = df.sort_values(by='Price')
sorted_df
# Out:
#       Product     Price  Units_Sold Price_Category Sales_Category
# 3  HEADPHONES    2000.0        80.0            Low     High Sales
# 4  SMARTWATCH    8000.0        50.0            Low   Medium Sales
# 1      MOBILE   20000.0        60.0         Medium   Medium Sales
# 2      TABLET   30000.0        35.0         Medium   Medium Sales
# 0      LAPTOP   55000.0        25.0           High      Low Sales
# 5      CAMERA  450000.0        15.0            NaN      Low Sales

# %%
#Display Unique Values
print(df['Price_Category'].unique())
# Out:
# ['High', 'Medium', 'Low', NaN]
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
#Dataset: Food Delivery Orders

data = {
    'Order_ID':[1,2,3,4,5,6,7,8],
    'Order_Value':[250,450,120,600,300,150,500,220],
    'Delivery_Time':[30,45,15,60,20,35,50,28],
    'Distance_km':[5,10,3,8,6,2,9,4]
}
df = pd.DataFrame(data)
df
# Out:
#    Order_ID  Order_Value  Delivery_Time  Distance_km
# 0         1          250             30            5
# 1         2          450             45           10
# 2         3          120             15            3
# 3         4          600             60            8
# 4         5          300             20            6
# 5         6          150             35            2
# 6         7          500             50            9
# 7         8          220             28            4

# %%
bins3=[0,20,40,60]
labels3=['Short','Medium','Long']
df['Delivery_Category'] = pd.cut(df['Delivery_Time'],bins=bins3, labels=labels3)
df
# Out:
#    Order_ID  Order_Value  Delivery_Time  Distance_km Delivery_Category
# 0         1          250             30            5            Medium
# 1         2          450             45           10              Long
# 2         3          120             15            3             Short
# 3         4          600             60            8              Long
# 4         5          300             20            6             Short
# 5         6          150             35            2            Medium
# 6         7          500             50            9              Long
# 7         8          220             28            4            Medium

# %%
bins4=[0,200,400,600]
labels4=['Affordable','Luxe','Gourmet']
df['MenuPrice_Category'] = pd.cut(df['Order_Value'],bins=bins4, labels=labels4)
df
# Out:
#    Order_ID  Order_Value  Delivery_Time  Distance_km Delivery_Category  \
# 0         1          250             30            5            Medium
# 1         2          450             45           10              Long
# 2         3          120             15            3             Short
# 3         4          600             60            8              Long
# 4         5          300             20            6             Short
# 5         6          150             35            2            Medium
# 6         7          500             50            9              Long
# 7         8          220             28            4            Medium
#
#   MenuPrice_Category
# 0               Luxe
# 1            Gourmet
# 2         Affordable
# 3            Gourmet
# 4               Luxe
# 5         Affordable
# 6            Gourmet
# 7               Luxe

# %%
bins5 = [0,3,6,10]
labels5 = ['Close','Medium','Far']
df['Distance_Category'] = pd.cut(df['Distance_km'],bins=bins5,labels=labels5)
df
# Out:
#    Order_ID  Order_Value  Delivery_Time  Distance_km Delivery_Category  \
# 0         1          250             30            5            Medium
# 1         2          450             45           10              Long
# 2         3          120             15            3             Short
# 3         4          600             60            8              Long
# 4         5          300             20            6             Short
# 5         6          150             35            2            Medium
# 6         7          500             50            9              Long
# 7         8          220             28            4            Medium
#
#   MenuPrice_Category Distance_Category
# 0               Luxe            Medium
# 1            Gourmet               Far
# 2         Affordable             Close
# 3            Gourmet               Far
# 4               Luxe            Medium
# 5         Affordable             Close
# 6            Gourmet               Far
# ...

# %%
#Data Formatting
#Convert Data Type

print(df.dtypes)

df['Distance_km'] = df['Distance_km'].astype(float)

df
# Out:
# Order_ID                 int64
# Order_Value              int64
# Delivery_Time            int64
# Distance_km              int64
# Delivery_Category     category
# MenuPrice_Category    category
# Distance_Category     category
# dtype: object
#    Order_ID  Order_Value  Delivery_Time  Distance_km Delivery_Category  \
# 0         1          250             30          5.0            Medium
# 1         2          450             45         10.0              Long
# 2         3          120             15          3.0             Short
# 3         4          600             60          8.0              Long
# 4         5          300             20          6.0             Short
# 5         6          150             35          2.0            Medium
# 6         7          500             50          9.0              Long
# 7         8          220             28          4.0            Medium
#
#   MenuPrice_Category Distance_Category
# 0               Luxe            Medium
# ...

# %%
#Convert Text to Uppercase
df['MenuPrice_Category'] = df['MenuPrice_Category'].str.upper()
df
# Out:
#    Order_ID  Order_Value  Delivery_Time  Distance_km Delivery_Category  \
# 0         1          250             30          5.0            Medium
# 1         2          450             45         10.0              Long
# 2         3          120             15          3.0             Short
# 3         4          600             60          8.0              Long
# 4         5          300             20          6.0             Short
# 5         6          150             35          2.0            Medium
# 6         7          500             50          9.0              Long
# 7         8          220             28          4.0            Medium
#
#   MenuPrice_Category Distance_Category
# 0               LUXE            Medium
# 1            GOURMET               Far
# 2         AFFORDABLE             Close
# 3            GOURMET               Far
# 4               LUXE            Medium
# 5         AFFORDABLE             Close
# 6            GOURMET               Far
# ...

# %%
#Sorting
print(df.sort_values(by='Order_Value'))
df
# Out:
#    Order_ID  Order_Value  Delivery_Time  Distance_km Delivery_Category  \
# 2         3          120             15          3.0             Short
# 5         6          150             35          2.0            Medium
# 7         8          220             28          4.0            Medium
# 0         1          250             30          5.0            Medium
# 4         5          300             20          6.0             Short
# 1         2          450             45         10.0              Long
# 6         7          500             50          9.0              Long
# 3         4          600             60          8.0              Long
#
#   MenuPrice_Category Distance_Category
# 2         AFFORDABLE             Close
# 5         AFFORDABLE             Close
# 7               LUXE            Medium
# 0               LUXE            Medium
# 4               LUXE            Medium
# 1            GOURMET               Far
# 6            GOURMET               Far
# ...
